# %% [markdown]
# #Домашнє завдання до теми "Синтаксис Python"
#
# В ДЗ першого модулю важливою умовою виконання завдань є те, що ми не імпортуємо жодних бібліотек, а робимо все на чистому Python, використовуючи лише базовий функціонал. Це необхідно аби відпрацювати роботу з базовими типами даних. А використовувати бібліотеки ми ще навчимось далі :)

# %% [markdown]
# 1. Створіть змінну, яка буде зберігати кількість яблук. І надайте їй значення 5. Виведіть значення змінної на екран.

# %%
apple_count = 5

# %% [markdown]
# 2. Виведіть тип змінної, створеної в завданні (1).

# %%
apple_count
# Out:
# 5

# %% [markdown]
# 3. Додайте до значення змінної, створеної в завданні (1) число `12` і виведіть результат на екран з допомогою команди `print()`.

# %%
print(apple_count + 12)
# Out:
# 17

# %% [markdown]
# 4. Запустіть код нижче аби створити дві змінні.

# %%
a = 48
b = 3

# %% [markdown]
# Створіть нову клітинку нижче цієї з допомогою натискання англійської літери `B`, коли ви НЕ в режимі редагування клітинки. В створеній клітинці створіть змінну `c`, яка буде містити результат ділення `a` на `b`.

# %%
c = a / b

# %%
c
# Out:
# 16.0

# %%
print(type(a)), 
print(type(b)), 
print(type(c))
# Out:
# <class 'int'>
# <class 'int'>
# <class 'float'>

# %% [markdown]
# Створіть ще одну нову клітинку, тільки тепер вище цієї. Для цього натисніть  англійську літеру `A`, коли ви НЕ в режимі редагування клітинки. Виведіть в новоствореній клітинці значення і тип кожної зі змінних `a`, `b`, `c`. Проаналізуйте результат.

# %% [markdown]
# У Python, коли ви ділите одне ціле число на інше, результат буде автоматично приведений до типу float, якщо він не є цілим числом. Це робиться для того, щоб забезпечити більш точний результат ділення, особливо коли результат міг би бути десятковим числом.

# %% [markdown]
# 5. Перегляньте наступний код, подумайте, що він виведе в результаті, та потім, запустіть його.

# %%
a = 10
a = 12
a = 15

b = 4
b = 8
b = 14

c = 3
c = 6
c = 9


a + b + c
# Out:
# 38

# %% [markdown]
# Відповідь. Саме таке значення, як результат коду, виведене, тому що програма виконує код послідовно. В даному випадку за основу взято значення змінної "a", що дорівнює останньому визначенню, тобто 15. Так по кожній окремій змінній.

# %% [markdown]
# В клітинці нижче закоментуйте деякі рядки так, аби в результаті виконання останнього рядка коду (`a + b + c`) вивелось `17`.
# Увага! Рядки треба саме закоментувати, а не видалити.
# Можна зручно коментувати рядки з допомогою комбінації клавіш `Ctrl + /` (`Command + /` для Mac)

# %%
a = 10
#a = 12
#a = 15

b = 4
#b = 8
#b = 14

c = 3
#c = 6
#c = 9


a + b + c
# Out:
# 17
